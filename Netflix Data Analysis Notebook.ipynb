# %% [markdown]
# # Netflix Data Analysis

# %% [markdown]
# The "Exploratory Data Analysis of Netflix TV Shows and Movies" project is a comprehensive analysis of the Netflix dataset, focusing on TV shows and movies available on the platform until the year 2021. This Jupyter Notebook project aims to provide valuable insights into the content, trends, and patterns found in the Netflix library.

# %%
# importing data

import pandas as pd
data = pd.read_csv(r"C:\Users\Aniruddha Shelke\Documents\Projects\Netflix Data Analysis\8. Netflix Dataset.csv")

# %%
# Data Description

data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# **Checking and removing duplicate records**

# %%
# Checking for duplicate records

data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# Removing the duplicate records from the original dataframe

data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# **Checking Null values**

# %%
# Checking Null values

data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
# Null values in each column

data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **To Retreive Details of a Show using it's title**

# %%
data['Title'].isin(['House Of Cards'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
# To find show id, name of director, cast, relelase date, Description etc. of any title

data[data['Title'].isin(['Breaking Bad'])]
# Out:
#      Show_Id Category         Title Director  \
# 1089   s1090  TV Show  Breaking Bad      NaN
#
#                                                    Cast        Country  \
# 1089  Bryan Cranston, Aaron Paul, Anna Gunn, Dean No...  United States
#
#         Release_Date Rating   Duration  \
# 1089  August 2, 2013  TV-MA  5 Seasons
#
#                                          Type  \
# 1089  Crime TV Shows, TV Dramas, TV Thrillers
#
#                                             Description
# 1089  A high school chemistry teacher dying of cance...

# %% [markdown]
# To find number of releases each year

# %%
# adding a new column with datatime datatype

data['Year'] = pd.to_datetime(data['Release_Date'])

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Year            datetime64[ns]
# dtype: object

# %%
data['Year'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Year, dtype: int64

# %%
# Plotting using a bar plot 

releases = data['Year'].dt.year.value_counts()

releases.plot(kind = 'bar', alpha = 0.5)
# Out:
# <Axes: >

# %% [markdown]
# **Number of TV Shows v/s Number of Movies**

# %%
data.groupby('Category')

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# **Plotting the data using a Pie chart**

# %%
df = data.groupby('Category').Category.count()

# %%
df.plot(kind = 'pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Category'>

# %% [markdown]
# **Finding out Titles of TV Shows released in India**

# %%
data[(data['Category'] == 'TV Show') & (data['Country'] == 'Mexico')] ['Title']
# Out:
# 12                                1994
# 800                 Becoming Champions
# 1437                     Club of Crows
# 1490                         Control Z
# 1534          Crime Diaries: Night Out
# 1535      Crime Diaries: The Candidate
# 1594                             Dandy
# 1613                       Dark Desire
# 1742                          Diablero
# 1949                          El Chavo
# 1955    El Dragón: Return of a Warrior
# 2894                          I Am Me!
# 2998                      Ingobernable
# 3228                        Juana Inés
# 3501                         La Piloto
# 3505              La Rosa de Guadalupe
# 3572                      Legend Quest
# 3573     Legend Quest: Masters of Myth
# 3691            Lo que la vida me robó
# 3815          Luis Miguel - The Series
# 4134                     Miss Dynamite
# 4173                           Monarca
# 5124                           Rebelde
# 5284                   Rosario Tijeras
# ...

# %% [markdown]
# **Finding out all the unique Ratings given by Netflix**

# %%
data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# **Sorting by Year Values**

# %%
data.sort_values(by = 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...
